# %%
import numpy as np
import matplotlib.pyplot as plt
import pynlo
import scipy

# %%
def torrToBar(pressure_Torr):
    """
    Convert the unit of gas pressure from Torr to Bar.
    1 torr is defined as exactly 1/760 of a standard atmosphere (101325 Pa), while
    1 pascal is equal to 1e-5 bar.
    
    Inputs:
    pressure_Torr: gas pressure [Torr]
    
    Outputs:
    pressure_Bar: gas pressure [Bar]
    """
    
    pressure_Pa = pressure_Torr * (101325/760)
    pressure_Bar = pressure_Pa * 1e-5
    
    return pressure_Bar

# %%
def calculateOutputFrequencyLimit(simulation_window, simulation_points):
    """
    Calculate the upper limit on the output frequency of the output pulse.
    
    Inputs:
    simulation_window: total time window of the simulation in picoseconds [ps]
    simulation_points: number of steps the simulation takes as the pulse propagates through the fiber
    
    Outputs:
    output_frequency_limit: upper limit on the frequency of the output pulse in THz [THz]
    """
    
    time_step = simulation_window / simulation_points
    sampling_rate = 1 / time_step
    output_frequency_limit = 0.5 * sampling_rate
    
    return output_frequency_limit

# %%
def nonlinearIndexN2(pressure, n2_at_one_bar):
    """
    Calculate the nonlinear refractive index n2.
    
    Inputs:
    pressure: pressure of the gas, constant or a function of the length along the fiber [Bar] or [Bar/m]
    n2_at_one_bar: nonlinear refractive index of the gas quoted at pressure = 1Bar [m^2/(W bar)]
    
    Outputs:
    n2: nonlinear refractive index n2 at specified pressure [m^2/W]
    """
    
    n2 = pressure * n2_at_one_bar
    
    return n2

# %%
def nonlinearParameterGamma(n2, pulseWL, fiber_rad):
    """
    Calculate the nonlinear parameter Gamma.
    Based on equation from Agrawal's "Nonlinear Fiber Optics": Gamma = (n2*omega0)/(c*A_eff)
    
    c: speed of light [m/s]
    omega0 = (2*pi*c)/pulseWL: angular frequency [rad/s]
    A_eff: effective core area of the fiber [m^2]
    
    Inputs:
    n2: nonlinear refractive index at specified pressure, can be a constant if gas pressure
    is constant along the length of the fiber, or an array if gas pressure varies [m^2/W]
    pulseWL: pulse central wavelength [nm]
    fiber_rad: radius of fiber [m]
    
    Outputs:
    Gamma: nonlinear parameter [1/(W km)]
    """
    
    Gamma = ((2*np.pi)/(pulseWL*1e-9)) * (n2/(np.pi*fiber_rad**2)) * (1/1e-3)
    
    return Gamma

# %%
# pulse parameters
FWHM = 0.16         # pulse duration (ps)
pulseWL = 1035      # fundamental pulse central wavelength (nm)
EPP = 2e-6          # Energy per pulse (J)
GDD = 0.0           # Group delay dispersion (ps^2)
TOD = 0.0           # Third order dispersion (ps^3)


# fibre parameters
Length = 100        # length in mm
Alpha = 0.0         # attentuation coefficient (dB/cm)
fiber_rad = 15e-6   # radius (m)
fibWL = pulseWL     # Center WL of fiber (nm)
alpha = np.log((10**(Alpha * 0.1))) * 100  # convert from dB/cm to 1/m


# Xenon gas at 800nm, dispersive coefficients (betas), pressure-dependent nonlinear refractive index (n2)
beta2 = 0.9113                    # (fs^2/cm)
beta3 = 0.7836                    # (fs^3/cm)
n2_Xe_at_one_bar = 1.115e-22      # (m^2/(W bar)), (Arnaud Couairon et al, 2008)

pressure = 2.31                                    # (bar)
n2 = nonlinearIndexN2(pressure, n2_Xe_at_one_bar)  # (m^2/W)

beta2 *= (1e-3)**2/1e-5           # (ps^2/km)
beta3 *= (1e-3)**3/1e-5           # (ps^3/km)
beta4 = 0                         # (ps^4/km) (value not found)

Gamma = nonlinearParameterGamma(n2, pulseWL, fiber_rad)  # (1/(W km))


# simulation parameters
Window = 2.5       # simulation window (ps)
Steps = 100         # simulation steps
Points = 2**15      # simulation points
Raman = True        # Enable Raman effect?
Steep = True        # Enable self steepening?

print(f"The proposed upper limit on the frequency of the output pulse is {calculateOutputFrequencyLimit(Window, Points)} THz.")
# Out:
# The proposed upper limit on the frequency of the output pulse is 6553.6 THz.

# %%
# customise Gamma from pressure gradient

xdata = np.array([0,20,40,60,80,90,100])*1e-3
ydata = torrToBar(np.array([1000.0,850.0,750.0,650.0,450.0,300.0,0.0]))

coeff = np.polyfit(xdata, ydata, 4)
customised_pressure = np.poly1d(coeff)

n2 = nonlinearIndexN2(customised_pressure, n2_Xe_at_one_bar)
Gamma = nonlinearParameterGamma(n2, pulseWL, fiber_rad)

# %%
# create the fundamental pulse
pulse_FD = pynlo.light.DerivedPulses.SechPulse(
    4, FWHM/1.76, pulseWL, time_window_ps=Window,
    GDD=GDD, TOD=TOD, NPTS=Points, frep_MHz=1, power_is_avg=True
)
pulse_FD.set_epp(EPP)

# create the second harmonic pulse
pulse_SH = pynlo.light.DerivedPulses.SechPulse(
    3, FWHM/1.76, pulseWL, time_window_ps=Window,
    GDD=GDD, TOD=TOD, NPTS=Points, frep_MHz=1, power_is_avg=True
)
pulse_SH = pulse_SH.interpolate_to_new_center_wl(pulseWL/2)
pulse_SH.set_epp(EPP)

# combine the pulses
pulse = pynlo.light.DerivedPulses.SechPulse(
    7, FWHM/1.76, pulseWL, time_window_ps=Window,
    GDD=GDD, TOD=TOD, NPTS=Points, frep_MHz=1, power_is_avg=True
)
pulse.set_AT(pulse_FD.AT + pulse_SH.AT)

# pulse = pynlo.light.PulseBase.Pulse()
# pulse.set_NPTS(Points)
# pulse.set_time_window_ps(Window)
# pulse.set_AT(pulse_FD.AT + pulse_SH.AT)

# create the combined pulse's spectrogram
plt.figure()
DELAYS, FREQS, extent, spectrogram = pulse.spectrogram()
plt.imshow(spectrogram, aspect='auto', extent=extent)
plt.xlabel('Time (ps)')
plt.ylabel('Frequency (THz)')
plt.show()

# %%
print(f"The fundamental pulse has center wavelength {pulse_FD.center_wavelength_nm} nm and center frequency {pulse_FD.center_frequency_THz} THz.")
print(f"The second harmonic pulse has center wavelength {pulse_SH.center_wavelength_nm} nm and center frequency {pulse_SH.center_frequency_THz} THz.")
print(f"The combined pulse has center wavelength {pulse.center_wavelength_nm} nm and center frequency {pulse.center_frequency_THz} THz.")
# Out:
# The fundamental pulse has center wavelength 1035.0 nm and center frequency 289.65454879227053 THz.
# The second harmonic pulse has center wavelength 517.5 nm and center frequency 579.3090975845411 THz.
# The combined pulse has center wavelength 1035.0 nm and center frequency 289.65454879227053 THz.

# %%
# create the fiber
fiber1 = pynlo.media.fibers.fiber.FiberInstance()
fiber1.generate_fiber(Length * 1e-3, center_wl_nm=fibWL, betas=(beta2, beta3, beta4),
                              gamma_W_m=Gamma(0) * 1e-3, gvd_units='ps^n/km', gain=-alpha)
fiber1.set_gamma_function(Gamma * 1e-3)

# fiberloader = pynlo.media.fibers.JSONFiberLoader.JSONFiberLoader()
# fiberloader.print_fiber_list()

# %%
# propagation
evol = pynlo.interactions.FourWaveMixing.SSFM.SSFM(local_error=0.001, USE_SIMPLE_RAMAN=True,
                 disable_Raman=np.logical_not(Raman),
                 disable_self_steepening=np.logical_not(Steep))

y, AW, AT, pulse_out = evol.propagate(pulse_in=pulse, fiber=fiber1, n_steps=Steps, reload_fiber_each_step=True)
# Out:
# Pulse energy before Simple Fiber : 3999.999999999993 nJ
# pulse energy in  15771690.97939292
# copied as   15771690.97939292
# Step: 0 Distance remaining: 0.1
# Pulse energy after: 3996.661558470851 nJ
# Step: 1 Distance remaining: 0.099
# Pulse energy after: 3996.7049804323315 nJ
# Step: 2 Distance remaining: 0.098
# Pulse energy after: 3996.759529660477 nJ
# Step: 3 Distance remaining: 0.097
# Pulse energy after: 3996.8223691981716 nJ
# Step: 4 Distance remaining: 0.096
# Pulse energy after: 3996.897881142346 nJ
# Step: 5 Distance remaining: 0.095
# Pulse energy after: 3996.982563757663 nJ
# Step: 6 Distance remaining: 0.094
# Pulse energy after: 3997.0626725936486 nJ
# Step: 7 Distance remaining: 0.093
# Pulse energy after: 3997.1281861973976 nJ
# Step: 8 Distance remaining: 0.09200000000000001
# Pulse energy after: 3997.1790952907236 nJ
# Step: 9 Distance remaining: 0.09100000000000001
# Pulse energy after: 3997.217737809204 nJ
# Step: 10 Distance remaining: 0.09000000000000001
# Pulse energy after: 3997.2383794639354 nJ
# Step: 11 Distance remaining: 0.08900000000000001
# Pulse energy after: 3997.2333827821617 nJ
# Step: 12 Distance remaining: 0.08800000000000001
# Pulse energy after: 3997.2054421233574 nJ
# Step: 13 Distance remaining: 0.08700000000000001
# Pulse energy after: 3997.1673102075474 nJ
# Step: 14 Distance remaining: 0.08600000000000001
# Pulse energy after: 3997.128337052428 nJ
# Step: 15 Distance remaining: 0.085
# Pulse energy after: 3997.0865573618003 nJ
# Step: 16 Distance remaining: 0.084
# Pulse energy after: 3997.037953114091 nJ
# Step: 17 Distance remaining: 0.083
# Pulse energy after: 3996.988435988553 nJ
# Step: 18 Distance remaining: 0.08200000000000002
# Pulse energy after: 3996.9515736403905 nJ
# Step: 19 Distance remaining: 0.08100000000000002
# Pulse energy after: 3996.9355468071153 nJ
# Step: 20 Distance remaining: 0.08000000000000002
# Pulse energy after: 3996.9380565830133 nJ
# Step: 21 Distance remaining: 0.07900000000000001
# Pulse energy after: 3996.9548998295563 nJ
# Step: 22 Distance remaining: 0.07800000000000001
# Pulse energy after: 3996.9883074600466 nJ
# Step: 23 Distance remaining: 0.07700000000000001
# Pulse energy after: 3997.042443736328 nJ
# Step: 24 Distance remaining: 0.07600000000000001
# Pulse energy after: 3997.1146324124416 nJ
# Step: 25 Distance remaining: 0.07500000000000001
# Pulse energy after: 3997.195775922818 nJ
# Step: 26 Distance remaining: 0.074
# Pulse energy after: 3997.2801097149536 nJ
# Step: 27 Distance remaining: 0.073
# Pulse energy after: 3997.3690558827802 nJ
# Step: 28 Distance remaining: 0.072
# Pulse energy after: 3997.463751070078 nJ
# Step: 29 Distance remaining: 0.071
# Pulse energy after: 3997.5572968174315 nJ
# Step: 30 Distance remaining: 0.06999999999999999
# Pulse energy after: 3997.6383026210146 nJ
# Step: 31 Distance remaining: 0.06899999999999999
# Pulse energy after: 3997.701541012771 nJ
# Step: 32 Distance remaining: 0.06799999999999999
# Pulse energy after: 3997.7506872945273 nJ
# Step: 33 Distance remaining: 0.06699999999999999
# Pulse energy after: 3997.790924079159 nJ
# Step: 34 Distance remaining: 0.06599999999999999
# Pulse energy after: 3997.8214540854415 nJ
# Step: 35 Distance remaining: 0.065
# Pulse energy after: 3997.8382547381666 nJ
# Step: 36 Distance remaining: 0.064
# Pulse energy after: 3997.8416900284547 nJ
# Step: 37 Distance remaining: 0.063
# Pulse energy after: 3997.837935181255 nJ
# Step: 38 Distance remaining: 0.062
# Pulse energy after: 3997.833104278638 nJ
# Step: 39 Distance remaining: 0.061
# Pulse energy after: 3997.8288091109707 nJ
# Step: 40 Distance remaining: 0.06
# Pulse energy after: 3997.8255990834227 nJ
# Step: 41 Distance remaining: 0.05900000000000001
# Pulse energy after: 3997.827966131598 nJ
# Step: 42 Distance remaining: 0.05800000000000001
# Pulse energy after: 3997.843223848199 nJ
# Step: 43 Distance remaining: 0.05700000000000001
# Pulse energy after: 3997.8750748507964 nJ
# Step: 44 Distance remaining: 0.05600000000000001
# Pulse energy after: 3997.921016219786 nJ
# Step: 45 Distance remaining: 0.05500000000000001
# Pulse energy after: 3997.977246304252 nJ
# Step: 46 Distance remaining: 0.054000000000000006
# Pulse energy after: 3998.04415601197 nJ
# Step: 47 Distance remaining: 0.053000000000000005
# Pulse energy after: 3998.1252893749606 nJ
# Step: 48 Distance remaining: 0.052000000000000005
# Pulse energy after: 3998.2213015695747 nJ
# Step: 49 Distance remaining: 0.051000000000000004
# Pulse energy after: 3998.327290345734 nJ
# Step: 50 Distance remaining: 0.05
# Pulse energy after: 3998.4365073579393 nJ
# Step: 51 Distance remaining: 0.049
# Pulse energy after: 3998.545135534409 nJ
# Step: 52 Distance remaining: 0.048
# Pulse energy after: 3998.652300933271 nJ
# Step: 53 Distance remaining: 0.047
# Pulse energy after: 3998.7565686264143 nJ
# Step: 54 Distance remaining: 0.046
# Pulse energy after: 3998.85453902568 nJ
# Step: 55 Distance remaining: 0.045
# Pulse energy after: 3998.9431014809124 nJ
# Step: 56 Distance remaining: 0.044
# Pulse energy after: 3999.021754903208 nJ
# Step: 57 Distance remaining: 0.04300000000000001
# Pulse energy after: 3999.091699234877 nJ
# Step: 58 Distance remaining: 0.04200000000000001
# Pulse energy after: 3999.1533319552127 nJ
# Step: 59 Distance remaining: 0.04100000000000001
# Pulse energy after: 3999.205859404214 nJ
# Step: 60 Distance remaining: 0.04000000000000001
# Pulse energy after: 3999.249283839181 nJ
# Step: 61 Distance remaining: 0.03900000000000001
# Pulse energy after: 3999.2858103388385 nJ
# Step: 62 Distance remaining: 0.038000000000000006
# Pulse energy after: 3999.3186658451077 nJ
# Step: 63 Distance remaining: 0.037
# Pulse energy after: 3999.3499149679565 nJ
# Step: 64 Distance remaining: 0.036
# Pulse energy after: 3999.37990442789 nJ
# Step: 65 Distance remaining: 0.034999999999999996
# Pulse energy after: 3999.4085695533263 nJ
# Step: 66 Distance remaining: 0.033999999999999996
# Pulse energy after: 3999.436555381383 nJ
# Step: 67 Distance remaining: 0.032999999999999995
# Pulse energy after: 3999.464752372134 nJ
# Step: 68 Distance remaining: 0.031999999999999994
# Pulse energy after: 3999.493237853639 nJ
# Step: 69 Distance remaining: 0.031000000000000007
# Pulse energy after: 3999.521074035963 nJ
# Step: 70 Distance remaining: 0.030000000000000006
# Pulse energy after: 3999.547006007409 nJ
# Step: 71 Distance remaining: 0.029000000000000005
# Pulse energy after: 3999.5699241613916 nJ
# Step: 72 Distance remaining: 0.028000000000000004
# Pulse energy after: 3999.588590682336 nJ
# Step: 73 Distance remaining: 0.027000000000000003
# Pulse energy after: 3999.6013759017465 nJ
# Step: 74 Distance remaining: 0.026000000000000002
# Pulse energy after: 3999.606639166523 nJ
# Step: 75 Distance remaining: 0.025
# Pulse energy after: 3999.6032967893643 nJ
# Step: 76 Distance remaining: 0.024
# Pulse energy after: 3999.5908050048724 nJ
# Step: 77 Distance remaining: 0.023
# Pulse energy after: 3999.5687416694914 nJ
# Step: 78 Distance remaining: 0.022
# Pulse energy after: 3999.536776028361 nJ
# Step: 79 Distance remaining: 0.020999999999999998
# Pulse energy after: 3999.495186411334 nJ
# Step: 80 Distance remaining: 0.019999999999999997
# Pulse energy after: 3999.4451716503813 nJ
# Step: 81 Distance remaining: 0.018999999999999996
# Pulse energy after: 3999.3883976706106 nJ
# Step: 82 Distance remaining: 0.018000000000000006
# Pulse energy after: 3999.326263459291 nJ
# Step: 83 Distance remaining: 0.017000000000000005
# Pulse energy after: 3999.2597735360173 nJ
# Step: 84 Distance remaining: 0.016000000000000004
# Pulse energy after: 3999.190024066024 nJ
# Step: 85 Distance remaining: 0.015000000000000003
# Pulse energy after: 3999.1184805563835 nJ
# Step: 86 Distance remaining: 0.014000000000000002
# Pulse energy after: 3999.046581392359 nJ
# Step: 87 Distance remaining: 0.013000000000000001
# Pulse energy after: 3998.975168562784 nJ
# Step: 88 Distance remaining: 0.012
# Pulse energy after: 3998.904492884055 nJ
# Step: 89 Distance remaining: 0.011
# Pulse energy after: 3998.8347171116275 nJ
# Step: 90 Distance remaining: 0.009999999999999998
# Pulse energy after: 3998.7661326400766 nJ
# Step: 91 Distance remaining: 0.008999999999999998
# Pulse energy after: 3998.6986892769646 nJ
# Step: 92 Distance remaining: 0.007999999999999997
# Pulse energy after: 3998.631429747005 nJ
# Step: 93 Distance remaining: 0.006999999999999996
# Pulse energy after: 3998.562667616829 nJ
# Step: 94 Distance remaining: 0.006000000000000005
# Pulse energy after: 3998.4908620215915 nJ
# Step: 95 Distance remaining: 0.0050000000000000044
# Pulse energy after: 3998.415276619304 nJ
# Step: 96 Distance remaining: 0.0040000000000000036
# Pulse energy after: 3998.335705087962 nJ
# Step: 97 Distance remaining: 0.0030000000000000027
# Pulse energy after: 3998.251609273255 nJ
# Step: 98 Distance remaining: 0.0020000000000000018
# Pulse energy after: 3998.1616767106366 nJ
# Step: 99 Distance remaining: 0.0010000000000000009
# Pulse energy after: 3998.064292579796 nJ
# Pulse energy after Simple Fiber : 3999.5572931171455 nJ

# %%
def hertzToElectronvolt(pulse):
    """
    Convert the unit of the angular frequency grid corresponding to the pulse
    instance's AW from Hertz to Electronvolt.
    
    Inputs:
    pulse: pulse instance
    
    Outputs:
    W_eV: angular frequency grid corresponding to AW [eV]
    """
    
    W_eV = scipy.constants.h * (pulse.W_mks / (2*np.pi)) / scipy.constants.e
    
    return W_eV

# %%
F = (pulse.W_mks / (2*np.pi)) * 1e-12 # convert to THz
# F = pulse.W_THz
W_eV = hertzToElectronvolt(pulse)

def dB(num):
    return 10 * np.log10(np.abs(num)**2)

zW = dB(np.transpose(AW)[:, (F > 0)])
zT = dB(np.transpose(AT))

# set up plots for the results:
fig = plt.figure(figsize=(10,10))
ax0 = plt.subplot2grid((3,2), (0, 0), rowspan=1)
ax1 = plt.subplot2grid((3,2), (0, 1), rowspan=1)
ax2 = plt.subplot2grid((3,2), (1, 0), rowspan=2, sharex=ax0)
ax3 = plt.subplot2grid((3,2), (1, 1), rowspan=2, sharex=ax1)


ax0.plot(W_eV[W_eV > 0], zW[-1], color='r')
ax1.plot(pulse.T_ps, zT[-1], color='r')

ax0.plot(W_eV[W_eV > 0], zW[0], color='b')
ax1.plot(pulse.T_ps, zT[0], color='b')


extent = (np.min(W_eV[W_eV > 0]), np.max(W_eV[W_eV > 0]), 0, Length)
ax2.imshow(zW, extent=extent, vmin=np.max(zW) - 250.0,
                 vmax=np.max(zW), aspect='auto', origin='lower', cmap='jet')

extent = (np.min(pulse.T_ps), np.max(pulse.T_ps), np.min(y), Length)
ax3.imshow(zT, extent=extent, vmin=np.max(zT) - 60.0,
           vmax=np.max(zT), aspect='auto', origin='lower', cmap='jet')


ax2.set_xlabel('Photon energy (eV)')
ax3.set_xlabel('Time (ps)')

ax0.set_ylabel('Intensity (dB)')
ax2.set_ylabel('Propagation distance (mm)')

# ax2.set_xlim(0,3)
ax0.set_ylim(-200,100)
ax1.set_ylim(-50,100)

plt.show()

# %% [markdown]
# ### The function `spectralPowerDensity` calculates the spectral power density in unit of watt per electronvolt from the intensity data (zW) in decibel:
#
# $${dB} = 10 \log_{10}\left(\frac{I}{I_0}\right)$$
#
# $$I = I_0 \times 10^{\frac{dB}{10}}$$
#
# $$P = I \times A_{eff}$$
#
# where the reference intensity $I_0$ can be obtained using:
#
# $$I_0 = \frac{P_{avg}}{A_{eff}} = \frac{E_{pulse} \times f_{rep}}{A_{eff}}$$
#
# The quantities used in the calculation can be traced back from pulse instances, in the example below, the values are derived from the output pulse instance `pulse_out`.
#
# Points that are not clear:
# 1. what should be the reference intensity $I_0$?
# 2. the meaning of the spectral power density is not clear, should we divide the power data by the value of one electronvolt? or it stands for the plot (power W as a function of electronvolt eV)?

# %%
F = (pulse.W_mks / (2*np.pi)) * 1e-12 # convert to THz
# F = pulse.W_THz
W_eV = hertzToElectronvolt(pulse)


def dB(num):
    return 10 * np.log10(np.abs(num)**2)


zW = dB(np.transpose(AW)[:, (F > 0)])
zT = dB(np.transpose(AT))


def spectralPowerDensity(pulse, zW):
    """
    Calculate the spectral power density in unit of watt per electronvolt from
    the intensity data in decibel.
    """
    effective_area = np.pi * fiber_rad**2  # [m^2]
    average_power = pulse.calc_epp() * pulse.frep_mks  # [W]
    intensity_in = average_power / effective_area  # [W / m^2]

    intensity_SI = 10**(zW/10) * intensity_in
    power_per_ev = intensity_SI * effective_area
    
    return power_per_ev


power_per_ev = spectralPowerDensity(pulse_out, zW)


# set up plots for the results:
fig = plt.figure(figsize=(10,10))
ax0 = plt.subplot2grid((3,2), (0, 0), rowspan=1)
ax1 = plt.subplot2grid((3,2), (0, 1), rowspan=1)
ax2 = plt.subplot2grid((3,2), (1, 0), rowspan=2, sharex=ax0)
ax3 = plt.subplot2grid((3,2), (1, 1), rowspan=2, sharex=ax1)

ax0.set_yscale('log')
ax0.plot(W_eV[W_eV > 0], power_per_ev[-1], color='r')
ax1.plot(pulse.T_ps, zT[-1], color='r')

# ax0.plot(W_eV[W_eV > 0], zW[0], color='b')
ax1.plot(pulse.T_ps, zT[0], color='b')


extent = (np.min(W_eV[W_eV > 0]), np.max(W_eV[W_eV > 0]), 0, Length)
ax2.imshow(zW, extent=extent, vmin=np.max(zW) - 250.0,
                 vmax=np.max(zW), aspect='auto', origin='lower', cmap='jet')

extent = (np.min(pulse.T_ps), np.max(pulse.T_ps), np.min(y), Length)
ax3.imshow(zT, extent=extent, vmin=np.max(zT) - 60.0,
           vmax=np.max(zT), aspect='auto', origin='lower', cmap='jet')


ax2.set_xlabel('Photon energy (eV)')
ax3.set_xlabel('Time (ps)')

ax0.set_ylabel('Spectral power density (W/eV)')
ax2.set_ylabel('Propagation distance (mm)')

# ax2.set_xlim(0,3)
ax1.set_ylim(-50,100)

plt.show()
